# %% [markdown]
# <a href="https://colab.research.google.com/github/gedeon31/pandasTigre/blob/main/PandasTigres1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-b23c53a3-df70-4647-abce-a772dda62aab" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b23c53a3-df70-4647-abce-a772dda62aab">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving pandas-tigres.zip to pandas-tigres.zip

# %%
# !pwd
# Out:
# /content

# %%
import zipfile
import io
data=zipfile.ZipFile(io.BytesIO(uploaded['pandas-tigres.zip']),'r')
data.extractall()

# %%
import cv2
import numpy as np
import os
import matplotlib.pyplot as plt
ruta_tigre="/content/tigres"
Tiger_train=[]
img_size=80
for img in os.listdir(ruta_tigre):
  img=cv2.imread(os.path.join(ruta_tigre,img))
  #img_gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
  img_gray_resize=cv2.resize(img_gray,(img_size,img_size))
  Tiger_train.append([img_gray_resize])
print(len(Tiger_train))
print(Tiger_train)
# Out:
# 6
# [[array([[ 97,  87,  82, ..., 130,  96, 116],
#        [110,  78,  71, ..., 170,  84, 104],
#        [ 75,  47,  45, ..., 173, 109,  94],
#        ...,
#        [ 35,  62,  74, ...,  98,  89,  28],
#        [ 22,  28,  14, ...,  63,  60,  57],
#        [ 44,  43,  22, ..., 102,  18,  31]], dtype=uint8)], [array([[ 97,  87,  82, ..., 130,  96, 116],
#        [110,  78,  71, ..., 170,  84, 104],
#        [ 75,  47,  45, ..., 173, 109,  94],
#        ...,
#        [ 35,  62,  74, ...,  98,  89,  28],
#        [ 22,  28,  14, ...,  63,  60,  57],
#        [ 44,  43,  22, ..., 102,  18,  31]], dtype=uint8)], [array([[ 97,  87,  82, ..., 130,  96, 116],
#        [110,  78,  71, ..., 170,  84, 104],
#        [ 75,  47,  45, ..., 173, 109,  94],
#        ...,
#        [ 35,  62,  74, ...,  98,  89,  28],
#        [ 22,  28,  14, ...,  63,  60,  57],
#        [ 44,  43,  22, ..., 102,  18,  31]], dtype=uint8)], [array([[ 97,  87,  82, ..., 130,  96, 116],
#        [110,  78,  71, ..., 170,  84, 104],
#        [ 75,  47,  45, ..., 173, 109,  94],
#        ...,
#        [ 35,  62,  74, ...,  98,  89,  28],
#        [ 22,  28,  14, ...,  63,  60,  57],
#        [ 44,  43,  22, ..., 102,  18,  31]], dtype=uint8)], [array([[ 97,  87,  82, ..., 130,  96, 116],
#        [110,  78,  71, ..., 170,  84, 104],
#        [ 75,  47,  45, ..., 173, 109,  94],
#        ...,
#        [ 35,  62,  74, ...,  98,  89,  28],
#        [ 22,  28,  14, ...,  63,  60,  57],
#        [ 44,  43,  22, ..., 102,  18,  31]], dtype=uint8)], [array([[ 97,  87,  82, ..., 130,  96, 116],
#        [110,  78,  71, ..., 170,  84, 104],
#        [ 75,  47,  45, ..., 173, 109,  94],
#        ...,
#        [ 35,  62,  74, ...,  98,  89,  28],
#        [ 22,  28,  14, ...,  63,  60,  57],
#        [ 44,  43,  22, ..., 102,  18,  31]], dtype=uint8)]]

# %%
plt.figure()
plt.imshow(np.squeeze(Tiger_train[0]))
plt.colorbar()
plt.grid(False)
plt.show()
